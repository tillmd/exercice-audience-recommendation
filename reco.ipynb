# %%
from group import Group
import pandas as pd
from ranking_engine import RankingEngine
from reco_engine import RecoEngine
from user import User
from utils import get_top_cooccurrence
from utils import load_data

# %%
data = load_data()
users = [User(i, tracks) for i, tracks in enumerate(data)]
group = Group(users)
reco_engine = RecoEngine(group)
ranking_engine = RankingEngine(reco_engine)

# %%
min_score = 0.8
reco_engine.make_reco(min_score, "id").head(100)
# Out:
#     nb_common_user      id                                             reco
# 0                5  778619                          {836713, 914010, 81495}
# 1                4  836713                           {84042, 778619, 81495}
# 2                4  252058  {934561, 350501, 836713, 84042, 625615, 778619}
# 3                4   81495                 {836713, 778619, 644718, 625615}
# 4                3  934561                                 {252058, 778619}
# 5                3  284579                         {836713, 350501, 625615}
# 6                3  184521                                         {934561}
# 7                3   84042                 {836713, 252058, 778619, 350501}
# 8                3  983724                                         {778619}
# 9                3  745042                         {836713, 350501, 625615}
# 10               3  389653                                         {836713}
# 11               3  858554                         {836713, 778619, 350501}
# 12               2  523936                                         {778619}
# 13               2   42474                                 {778619, 625615}
# 14               2  988837                                 {836713, 778619}
# 15               2  625615                           {42474, 778619, 81495}
# 16               2  843495                                 {778619, 644718}
# 17               2  368840                                 {836713, 625615}
# 18               2  566099                                 {836713, 625615}
# 19               2  252202                                 {778619, 337629}
# 20               2  573195                                  {934561, 84042}
# 21               2  754380                          {934561, 84042, 778619}
# 22               2  644718          {778619, 836713, 81495, 350501, 625615}
# 23               2  508303                                               {}
# 24               2  237363                                         {644718}
# 25               2  238446                                         {778619}
# 26               2  108408                 {836713, 778619, 350501, 337629}
# 27               2  914010                                 {836713, 778619}
# 28               2  965947                         {836713, 350501, 625615}
# 29               2  874012                                  {934561, 84042}
# 30               2  337629                 {108408, 252202, 778619, 350501}
# 31               2  350501                                  {84042, 778619}

# %%
min_score = 0.6
reco_engine.make_reco(min_score, "artist").head(17)
# Out:
#     nb_common_user         artist  \
# 0               10  The Offspring
# 1               10            M83
# 2               10   Stellardrone
# 3                9      Daft Punk
# 4                9        Madonna
# 5                9     Confection
# 6                9        Kaskade
# 7                8          Lenka
# 8                7         Gossip
# 9                7     Fred Falke
# 10               4      Alex Hook
# 11               4    Duke Dumont
#
#                                                  reco
# 0                                            0.606658
# 1                                            0.688454
# 2                                            0.658578
# 3   {Miguel Campbell, Agnes Obel, Fred Falke, Le M...
# 4   {Daft Punk, Pink, Lifelike, Fred Falke, Le Mar...
# 5   {Daft Punk, Pink, Lifelike, Sade, Kaskade, Agn...
# 6   {Daft Punk, Pink, Le Marquis, Fred Falke, Sade...
# 7   {Miguel Campbell, Kaskade, Stellardrone, Agnes...
# 8   {Miguel Campbell, Kaskade, Stellardrone, Agnes...
# 9   {Daft Punk, Pink, Lifelike, Le Marquis, Stevie...
# 10                                  {Miguel Campbell}
# 11  {Miguel Campbell, Kaskade, Fred Falke, Stellar...

# %%
res = ranking_engine.make_ranking(0.65)
res
# Out:
#                  artist      genre     score
# 1                 First       ----  0.000000
# 11           FirstFirst       ----  0.000000
# 778619       Confection    Electro  0.999055
# 603366       Agnes Obel      Vocal  0.740164
# 943547          Madonna   Acoustic  0.727880
# 836713  Miguel Campbell      Blues  0.989837
# 81495      Stellardrone   Acoustic  0.959528
# 252058            Lenka    Electro  0.929338
# 324595         Kristine       Rock  0.789607
# 949085            Booba      Disco  0.708989
# 934561        Daft Punk        RnB  0.998326
# 184521  Michael Jackson       Jazz  0.995573
# 389653      Bob Sinclar       Jazz  0.955620
# 84042        Fred Falke      Blues  0.950942
# 745042              M83    Electro  0.907286
# 858554     Stellardrone   Acoustic  0.895695
# 284579           Mozart    Electro  0.862262
# 983724  Miguel Campbell      Blues  0.823481
# 838786             Sade      Blues  0.754565
# 142442             Pink        RnB  0.752770
# 341845          Kaskade      Blues  0.748536
# 950235         Lifelike      Vocal  0.737601
# 802047         Kristine       Rock  0.733717
# 655207      Bob Sinclar       Jazz  0.695036
# 623587           Gossip       Funk  0.663447
# 596994          Kaskade      Blues  0.663145
# 965947          Kaskade      Blues  0.993626
# 237363    The Offspring        RnB  0.993168
# 843495          Kaskade      Blues  0.977140
# 337629        Daft Punk        RnB  0.973769
# ...                 ...        ...       ...
# 739863       The Weeknd      Metal  0.192828
# 298347          Madonna   Acoustic  0.188759
# 910689           Mozart    Electro  0.188219
# 646473         Lifelike      Vocal  0.183879
# 650920     Eric Clapton        RnB  0.181882
# 792126             Muse  Classical  0.180188
# 571442       Le Marquis    Electro  0.177873
# 207034     Eric Clapton        RnB  0.177320
# 747324        Daft Punk        RnB  0.176939
# 793860          Rihanna      Disco  0.159164
# 650282         Coldplay        Pop  0.154121
# 412593     Nora En Pure       Jazz  0.152395
# 385039  Miguel Campbell      Blues  0.149177
# 851181     David Guetta        Pop  0.147755
# 334955       Le Marquis    Electro  0.145766
# 440823      Bob Sinclar       Jazz  0.144048
# 264021         Lifelike      Vocal  0.141358
# 36771              Sade      Blues  0.141141
# 951701             Pink        RnB  0.139806
# 742332       Agnes Obel      Vocal  0.114671
# 683081     David Guetta        Pop  0.114632
# 600244             2be3       Funk  0.114520
# 651342  Michael Jackson       Jazz  0.113217
# 800931      Bob Sinclar       Jazz  0.113018
# 67150            Mozart    Electro  0.110449
# 972419             Mika    Electro  0.109949
# 256280         Lifelike      Vocal  0.108353
# 937838       Le Marquis    Electro  0.107251
# 165180           Eminem        RnB  0.104453
# 914561      Craig David       Rock  0.101233
#
# [257 rows x 3 columns]

# %% [markdown]
# 76 tracks over the 128 were sorted using the recommendation system.
