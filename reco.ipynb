# %%
from group import Group
import pandas as pd
from ranking_engine import RankingEngine
from reco_engine import RecoEngine
from user import User
from utils import get_top_cooccurrence
from utils import load_data

# %%
data = load_data()
users = [User(i, tracks) for i, tracks in enumerate(data)]
group = Group([users[1], users[3], users[8]])
reco_engine = RecoEngine(group)
ranking_engine = RankingEngine(reco_engine)

# %%
min_score = 0.8
reco_engine.make_reco(min_score, "id").head(10)
# Out:
#    nb_common_user      id                                     reco
# 0               3  745042                                 0.907286
# 1               2  463113                                       {}
# 2               2  508303  {836713, 745042, 284579, 252058, 81495}
# 3               2  503569                                       {}
# 4               2  879769                                       {}
# 5               2  252058  {836713, 745042, 508303, 184521, 81495}
# 6               2  158238                                       {}
# 7               2  284579                 {745042, 983724, 508303}
# 8               2  983724                  {745042, 284579, 81495}
# 9               2  533677                                       {}

# %%
min_score = 0.8
reco_engine.make_reco(min_score, "artist").head(17)
# Out:
#     nb_common_user           artist  \
# 0                3  Miguel Campbell
# 1                3       Agnes Obel
# 2                3          Kaskade
# 3                3     Stellardrone
# 4                3      Bob Sinclar
# 5                3              M83
# 6                3             Muse
# 7                3           Eminem
# 8                3         Kristine
# 9                3           Gossip
# 10               3          Madonna
# 11               3         Lifelike
# 12               3    The Offspring
# 13               3            Lenka
# 14               3  Michael Jackson
# 15               2        Daft Punk
# 16               2             Pink
#
#                                                  reco
# 0                                            0.632198
# 1                                            0.480362
# 2                                            0.743556
# 3                                            0.721456
# ...

# %%
res = ranking_engine.make_ranking(0.5)
res
# Out:
# /home/till/code/prizm/Exercice2/venv/local/lib/python2.7/site-packages/pandas/core/generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# ranking_engine.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   selected_artists['score'] = selected_artists.artist.apply(lambda x: self.get_top_tracks_per_artist(x).score.mean())
#                  artist      genre     score
# 1                 First       ----  0.000000
# 745042              M83    Electro  0.907286
# ...

# %% [markdown]
# 76 tracks over the 128 were sorted using the recommendation system.
